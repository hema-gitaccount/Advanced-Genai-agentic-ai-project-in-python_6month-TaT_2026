# %% [markdown]
# # Welcome to Python programming language

# %% [markdown]
# ![image.png](attachment:1873aca2-eaa2-4a9c-8d83-69a539ce78fc.png)

# %%
import sys
sys.version
# Out:
# '3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]'

# %%
a=5
b=7
a+b
# Out:
# 12

# %%
_
# Out:
# 12

# %%
_ -6
# Out:
# 6

# %%
_+6+20
# Out:
# 32
