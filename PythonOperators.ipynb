# %% [markdown]
# # Python Operators
#  - Arithmetic Operators  --->  +, _, *, /, //, %
#  - Assignment Operators  --->  = (+=, -=, /=, //=, *=)
#  - Relational Operators  --->  <, >, <=, >=, ==, !=
#  - Logical Operators     --->  and, or, not
#  - Unary Operator        --->  unary means 1 || binary means 2. Here we are applying unary minus operator(-) on the operand n; the value of m becomes -7, which indicates it as a negative vaue

# %% [markdown]
# # Arithmetic Operators

# %%
x1, y1= 10, 5
x1 + y1
# Out:
# 15

# %%
x1 - y1
# Out:
# 5

# %%
x1 * y1
# Out:
# 50

# %%
x1/y1
# Out:
# 2.0

# %%
x1//y1
# Out:
# 2

# %%
x1%y1 # reminder
# Out:
# 0

# %%
2 * 3
# Out:
# 6

# %%
2 ** 3 # 2 power of 3
# Out:
# 8

# %% [markdown]
# # Assignment Operator

# %%
x = 2
x = x + 2
x
# Out:
# 4

# %%
x += 2
x
# Out:
# 6

# %%
x *= 2
x
# Out:
# 12

# %%
x -= 2
x
# Out:
# 10

# %%
x * = 2 #space shouldn't be there
x
# Out:
#   Cell In[16], line 1
#     x * = 2
#         ^
# SyntaxError: invalid syntax

# %%
x *= 2
x
# Out:
# 20

# %%
x //= 2
x
# Out:
# 10

# %%
x /= 2
x
# Out:
# 5.0

# %% [markdown]
# # Unary Operator

# %%
n = 7 # negation
n
# Out:
# 7

# %%
m = -n
m
# Out:
# -7

# %%
-n
# Out:
# -7

# %% [markdown]
# # Relational Operator

# %%
a = 9
b = 6
a < b
# Out:
# False

# %%
a > b
# Out:
# True

# %%
print(a)
print(b)
# Out:
# 9
# 6

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
a <= b
# Out:
# False

# %%
a >= b
# Out:
# True

# %% [markdown]
# # Logical Table

# %%
a = 5
b = 4
a < 8 and b < 5 # True and True = True
# Out:
# True

# %%
a < 8 or b < 5
# Out:
# True

# %%
a < 8 and b > 5
# Out:
# False

# %%
x = True
x
# Out:
# True

# %%
not x
# Out:
# False

# %%
-True
# Out:
# -1

# %%
-False
# Out:
# 0

# %%
10 + 3 * (2 - 1) # BODMAS RULE
# Out:
# 13

# %%
print(10)
print(10,20)
print('python')
print(10,20,'python')
# Out:
# 10
# 10 20
# python
# 10 20 python

# %%
num1 = 20
num2 = 40
add = num1 + num2
print(add)
# Out:
# 60

# %%
a, b, c, d, e = 2, 3.4, 3.5j, True, "python"
print(a, b, c, d, e)
print(a)
print(b)
print(c)
print(d)
print(e)
print(type(c))
# Out:
# 2 3.4 3.5j True python
# 2
# 3.4
# 3.5j
# True
# python
# <class 'complex'>
