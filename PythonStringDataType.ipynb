# %% [markdown]
# # Python Datatypes

# %% [markdown]
# # integer

# %%
i = 5
type()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 i =5
# ----> 2 type()
#
# TypeError: type() takes 1 or 3 arguments

# %%
type(i)
# Out:
# int

# %%
id(i) # fetch the memory location
# Out:
# 140729468953640

# %% [markdown]
# # float

# %%
f = 110.45
f
# Out:
# 110.45

# %%
type(f)
# Out:
# float

# %%
f1 = 2.4e1 # e0 = 1, e1 = 10.0 , e2 = 100.0, e3 = 1000.0 -----
f1
# Out:
# 24.0

# %%
f2 = 2.4e2
f2
# Out:
# 240.0

# %%
type(f2)
# Out:
# float

# %%
f3 = 4.2E4
f3
# Out:
# 42000.0

# %% [markdown]
# # Boolean

# %%
True
# Out:
# True

# %%
True  + True # 1 + 1
# Out:
# 2

# %%
True + False # 1 + 0
# Out:
# 1

# %%
True * True
# Out:
# 1

# %%
False / True # float division
# Out:
# 0.0

# %%
False // True
# Out:
# 0

# %%
True / False # 1 / 0 = infinity so error
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 True / False
#
# ZeroDivisionError: division by zero

# %%
int(True)
# Out:
# 1

# %%
b = True # True = 1 and False = 0
b1 = False
c = b + b1
c
# Out:
# 1

# %%
type(c)
# Out:
# int

# %%
b = False
type(b)
# Out:
# bool

# %% [markdown]
# # Complex

# %%
c = 10+20j # 10 - real part @ 20j is imaginary [art where j = square root of -1
type(c)
# Out:
# complex

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 20.0

# %%
c1 = 3+4j
print(c)
print(c1)
# Out:
# (10+20j)
# (3+4j)

# %%
c + c1
# Out:
# (13+24j)

# %% [markdown]
# # Integer, float, boolean, complex datatypes completed

# %% [markdown]
# # String datatype

# %%
'Welcome to python' # it will work with single quotes
# Out:
# 'Welcome to python'

# %%
"Welcome to python" # it will work with double quotes
# Out:
# 'Welcome to python'

# %%
'Welcome  # multiline comments works only with triple quotes ''' '''
to
python'
# Out:
#   Cell In[40], line 1
#     'Welcome  # multiline comments works only with triple quotes ''' '''
#                                                                      ^
# _IncompleteInputError: incomplete input

# %%
'''Welcome  
to 
python'''  # multiline comments works only with triple quotes ''' '''
# Out:
# 'Welcome  \nto \npython'

# %%
s = 'python'
s
# Out:
# 'python'

# %%
s1 = 'welcome'
s1[3]
# Out:
# 'c'

# %%
s1[5]
# Out:
# 'm'

# %%
s1[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 s1[10]
#
# IndexError: string index out of range

# %%
s1[-1]
# Out:
# 'e'

# %%
s1[-5]
# Out:
# 'l'

# %%
s1[-4]
# Out:
# 'c'

# %%
len(s1)
# Out:
# 7

# %%
s1
# Out:
# 'welcome'

# %%
s1[:] # print whole string
# Out:
# 'welcome'

# %%
s1[1:4]  # forward slicing
# Out:
# 'elc'

# %%
s2 = 'nareshtechnology'
s2
# Out:
# 'nareshtechnology'

# %% [markdown]
# len(s2)

# %%
s2[:]
# Out:
# 'nareshtechnology'

# %%
s1 = 'hello'
s1
# Out:
# 'hello'

# %%
s1[1:3] # it will print from 1st index to n-1(2nd index) index
# Out:
# 'el'

# %%
s1[:5]
# Out:
# 'hello'

# %%
s1[:4]
# Out:
# 'hell'

# %%
s1[0:2:4]
# Out:
# 'h'

# %%
str = 'woohoo '
str = str * 5
str
# Out:
# 'woohoo woohoo woohoo woohoo woohoo '

# %%
len(str)
# Out:
# 35

# %%
mystr = 'HELLO PYTHON'
mystr
# Out:
# 'HELLO PYTHON'

# %%
mystr[0] # First character in string
# Out:
# 'H'

# %%
mystr[len(mystr)-1] # Last character in string using len() function(len-1)
# Out:
# 'N'

# %%
mystr[-1] # Last character in string # backward indexing starts from -1 -2 ....
# Out:
# 'N'

# %%
mystr[6] # Fetch 7th element of string
# Out:
# 'P'

# %%
mystr[5]
# Out:
# ' '

# %% [markdown]
# # String Slicing

# %%
mystr[0:5] # String slicing - Fetch all characters from 0th index to (5-1)th index
# Out:
# 'HELLO'

# %%
mystr[6:12]
# Out:
# 'PYTHON'

# %%
mystr[-4:] # Retreive last four characters of the string
# Out:
# 'THON'

# %%
mystr[-6:] # Retreive last four characters of the string
# Out:
# 'PYTHON'

# %%
mystr[:-4] # Retreive 0th index to -4th index
# Out:
# 'HELLO PY'

# %%
mystr[:4] # Retreive first four characters of the string
# Out:
# 'HELL'

# %%
mystr[:6] # Retreive first six characters of the string
# Out:
# 'HELLO '

# %% [markdown]
# # Update and Delete String

# %%
mystr
# Out:
# 'HELLO PYTHON'

# %%
mystr[0:5] = 'Wohooo' # bcz Strings are immutable objects, which means elements of string can't be changed once assigned.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 mystr[0:5] = 'Wohooo'
#
# TypeError: 'str' object does not support item assignment

# %%
del mystr # delete a string
print(mystr) # error bcz it's already deleted in above line
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 2
#       1 del mystr # delete a string
# ----> 2 print(mystr)
#
# NameError: name 'mystr' is not defined

# %% [markdown]
# # String Concatenation

# %%
s1 = "Hello"
s2 = " World"
s3 = s1 + s2
print(s3)
# Out:
# Hello World
