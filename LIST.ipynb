# %% [markdown]
# # List Datastructure

# %%
l = []
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %% [markdown]
# # append()

# %%
l.append(10)
l
# Out:
# [10]

# %%
l.append(20) # add element at last
l
# Out:
# [10, 20]

# %%
l.append(30)
l.append(40)
l.append(50)
l
# Out:
# [10, 20, 30, 40, 50]

# %%
len(l)
# Out:
# 5

# %%
l.append(10)
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l1 = [10, 2.3, 1+2j, True, 'Hema', [1,2,3]]
l1
# Out:
# [10, 2.3, (1+2j), True, 'Hema', [1, 2, 3]]

# %%
len(l1)
# Out:
# 6

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 2.3, (1+2j), True, 'Hema', [1, 2, 3]]

# %%
print(id(l))
print(id(l1))
# Out:
# 2627191987904
# 2627186883200

# %%
print(l)
# Out:
# [10, 20, 30, 40, 50, 10]

# %% [markdown]
# # copy()

# %%
l2.copy(l1) # l2 list is not defined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 l2.copy(l1)
#
# NameError: name 'l2' is not defined

# %%
l2 = l.copy()
l2
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
print(id(l))
print(id(l1))
print(id(l2))
# Out:
# 2627191987904
# 2627186883200
# 2627199852864

# %%
len(l2)
# Out:
# 6

# %% [markdown]
# # clear()

# %%
l2.clear()

# %%
print(l2) # empty list bcz the list is cleared before
# Out:
# []

# %%
len(l2)
# Out:
# 0

# %%
del l2

# %%
l2 # once we clear the list the list elements will be cleared, once we delete the list , it will be deleted
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 l2
#
# NameError: name 'l2' is not defined

# %%
print(l)
# Out:
# [10, 20, 30, 40, 50, 10]

# %% [markdown]
# # count()

# %%
l.count(10) # it will return number of occurances of list value
# Out:
# 2

# %%
l.count(20)
# Out:
# 1

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 2.3, (1+2j), True, 'Hema', [1, 2, 3]]

# %% [markdown]
# # extend()

# %%
a = [1,2,3]
b = [4,5,6]

a.extend(b) #extend the list which mreans merging the list
a
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l2 = []
l2
# Out:
# []

# %%
l2.extend(l)
l2
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
print(l1)
l2.extend(l1)
print(l2)
# Out:
# [10, 2.3, (1+2j), True, 'Hema', [1, 2, 3]]
# [10, 20, 30, 40, 50, 10, 10, 2.3, (1+2j), True, 'Hema', [1, 2, 3]]

# %%
print(l)
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l[0] = 100 # List is mutable, we can change the value once it is defined
print(l)
# Out:
# [100, 20, 30, 40, 50, 10]

# %%
# example job -> you joined as 5k salary next incremented to 10,000 in this use case we can use list
job = [5000]
job
# Out:
# [5000]

# %%
job[0] = 10000
print(job)
# Out:
# [10000]

# %%
print(l)
# Out:
# [100, 20, 30, 40, 50, 10]

# %%
l[-2] = 500
print(l)
# Out:
# [100, 20, 30, 40, 500, 10]

# %% [markdown]
# # slicing

# %%
l[:]
# Out:
# [100, 20, 30, 40, 500, 10]

# %%
l[::]
# Out:
# [100, 20, 30, 40, 500, 10]

# %%
l[:6:2]
# Out:
# [100, 30, 500]

# %%
l[:-6:-3]
# Out:
# [10, 30]

# %% [markdown]
# # index()

# %%
print(l)
# Out:
# [100, 20, 30, 40, 500, 10]

# %%
l.index(500) # index of 500 element is 4
# Out:
# 4

# %%
l[5] = 100
print(l)
# Out:
# [100, 20, 30, 40, 500, 100]

# %%
l.index(100) # index function print always first index of value
# Out:
# 0

# %% [markdown]
# # insert()

# %%
l.insert(2, 25) # insert 25 at 2nd index
print(l)
# Out:
# [100, 20, 25, 30, 40, 500, 100]

# %%
l.insert(1, 13) # insert 13 at 1st index
print(l)
# Out:
# [100, 13, 20, 25, 30, 40, 500, 100]

# %% [markdown]
# # pop()

# %%
print(l2)
# Out:
# [10, 20, 30, 40, 50, 10, 10, 2.3, (1+2j), True, 'Hema', [1, 2, 3]]

# %%
l2.pop() # if we use pop() function bydefault it will remove last element in the list
print(l2)
# Out:
# [10, 20, 30, 40, 50, 10, 10, 2.3, (1+2j), True, 'Hema']

# %%
l2.pop(-4)
print(l2)
# Out:
# [10, 20, 30, 40, 50, 10, 10, (1+2j), True, 'Hema']

# %%
l2.pop() # it has removed last element
# Out:
# 'Hema'

# %%
l2.pop()
# Out:
# True

# %% [markdown]
# # remove()

# %%
print(l2)
# Out:
# [10, 20, 30, 40, 50, 10, 10, (1+2j)]

# %%
l2.remove(10)

# %%
print(l2) # remove() will remove first occurance of value
# Out:
# [20, 30, 40, 50, 10, 10, (1+2j)]

# %%
l2.remove(10)

# %%
print(l2)
# Out:
# [20, 30, 40, 50, 10, (1+2j)]

# %%
l2.append(10)
l2
# Out:
# [20, 30, 40, 50, 10, (1+2j), 10]

# %%
l2.insert(0,10)
l2
# Out:
# [10, 20, 30, 40, 50, 10, (1+2j), 10]

# %% [markdown]
# # reverse()

# %%
print(l2)
# Out:
# [10, 20, 30, 40, 50, 10, (1+2j), 10]

# %%
l2.reverse() # reverse the list
print(l2)
# Out:
# [10, (1+2j), 10, 50, 40, 30, 20, 10]

# %% [markdown]
# # sort()

# %%
print(l)
# Out:
# [100, 13, 20, 25, 30, 40, 500, 100]

# %%
l.sort() #ascending order
print(l)
# Out:
# [13, 20, 25, 30, 40, 100, 100, 500]

# %%
l.sort(reverse = True) # descending order
print(l)
# Out:
# [500, 100, 100, 40, 30, 25, 20, 13]

# %%
l3 = [10, 20, [2,3], 3]
print(l3)
# Out:
# [10, 20, [2, 3], 3]

# %%
l3[2] = [2]
l3
# Out:
# [10, 20, [2], 3]

# %%
print(l)
# Out:
# [500, 100, 100, 40, 30, 25, 20, 13]

# %%
500 in l
# Out:
# True

# %%
501 in l
# Out:
# False

# %%
for i in l:
    print(i)
# Out:
# 500
# 100
# 100
# 40
# 30
# 25
# 20
# 13
