# %% [markdown]
# # Variable declaration in Python (variable = object = identifier)
#   - variable(object) = value(datatype)

# %%
nit = 1030
nit
# Out:
# 1030

# %%
1030 = nit  # value = variable is invalid
# Out:
#   Cell In[2], line 1
#     1030 = nit
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
12nit = 100 # varibles sshould not start with numbers
# Out:
#   Cell In[3], line 1
#     12nit = 100
#      ^
# SyntaxError: invalid decimal literal

# %%
nit12 = 10
nit12
# Out:
# 10

# %%
nit1 = 50 # variables are case sensitive, you have to call it with the corresponding case
NIT1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 nit1 = 50
# ----> 2 NIT1
#
# NameError: name 'NIT1' is not defined

# %%
nit@ = 10 # special characters are not allowed 
nit@
# Out:
#   Cell In[6], line 1
#     nit@ = 10
#          ^
# SyntaxError: invalid syntax

# %%
nit2_ab = 10 # only underscore special char is allowed
nit2_ab
# Out:
# 10

# %%
nit_ = 32
nit_
# Out:
# 32

# %%
_nit =5
_nit
# Out:
# 5

# %%
_
# Out:
# 5

# %%
_+10
# Out:
# 15

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 len(keyword)
#
# TypeError: object of type 'module' has no len()

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
for = 43  # reserved words should not declare as variable
for
# Out:
#   Cell In[16], line 1
#     for = 43
#         ^
# SyntaxError: invalid syntax

# %%
For = 43 # bcz For is not reserved word , the reserved word is for since it is case sensitive
For
# Out:
# 43

# %%
if = 76
if
# Out:
#   Cell In[19], line 1
#     if = 76
#        ^
# SyntaxError: invalid syntax

# %%
else = 7 # reserved words should not declare as variable
# Out:
#   Cell In[20], line 1
#     else = 7
#     ^
# SyntaxError: invalid syntax

# %%
true = 10
true
# Out:
# 10

# %%
True = 10 # reserved words should not declare as variable
# Out:
#   Cell In[23], line 1
#     True = 10
#     ^
# SyntaxError: cannot assign to True

# %% [markdown]
# # Python variable completed
