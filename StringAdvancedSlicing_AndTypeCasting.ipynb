# %% [markdown]
# # Python - String advanced slicing

# %%
str = "WelcomeTeam"
str
# Out:
# 'WelcomeTeam'

# %%
str[1:5]
# Out:
# 'elco'

# %%
str[1:8:3] # where 1 is start index, 8(8-1) is end index, 3 is step index
# Out:
# 'eoT'

# %%
str[2:9:4]
# Out:
# 'le'

# %%
str[::1] # it will print whole string
# Out:
# 'WelcomeTeam'

# %%
str[::3]
# Out:
# 'Wcea'

# %%
str[::2]
# Out:
# 'Wloeem'

# %%
str
# Out:
# 'WelcomeTeam'

# %%
str[::-1]
# Out:
# 'maeTemocleW'

# %%
str[::-2]
# Out:
# 'meeolW'

# %%
str[::-4]
# Out:
# 'mel'

# %% [markdown]
# # Python Type casting
#  - car() -- car function without argument(parameter)
#  - asian_cars('tata','to') -- car function with 2 argument(parameters) | String argument
#  - german_cars('audi','bmw','fereri','vw') -- german_cars function with 4 arguments(parameters)
#  - function ends with ():

# %% [markdown]
# # All other data types to Integer

# %%
int(2.3)
# Out:
# 2

# %%
int(2.3, 4.6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 int(2.3, 4.6)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 int(1+2j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('10')
# Out:
# 10

# %%
int('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 int('ten')
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %% [markdown]
# # All other data types to float

# %%
float(20)
# Out:
# 20.0

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float('20')
# Out:
# 20.0

# %%
float('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 float('ten')
#
# ValueError: could not convert string to float: 'ten'

# %%
float(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 float(1+2j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %% [markdown]
# # All other datatypes to boolean

# %%
bool(2)
# Out:
# True

# %%
bool(2.2)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(1+2j)
# Out:
# True

# %%
bool('10')
# Out:
# True

# %%
bool('ten')
# Out:
# True

# %%
bool(' ')
# Out:
# True

# %%
bool( ) # bool of space = False
# Out:
# False

# %%
bool('zero')
# Out:
# True

# %%
val1 = [20, 30, 40, 50]
val1
# Out:
# [20, 30, 40, 50]

# %%
import sys
sys.getsizeof(val1)
# Out:
# 88

# %% [markdown]
# # All other datatypes to complex

# %%
complex(3)
# Out:
# (3+0j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
complex(4.2)
# Out:
# (4.2+0j)

# %%
complex('10')
# Out:
# (10+0j)

# %%
complex('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 complex('ten')
#
# ValueError: complex() arg is a malformed string
