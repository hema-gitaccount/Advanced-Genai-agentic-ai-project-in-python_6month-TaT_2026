# %% [markdown]
# # math function

# %%
x = sqrt(25) # bcz didn't import math function
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 x = sqrt(25)
#
# NameError: name 'sqrt' is not defined

# %%
import math
math.sqrt(25)
# Out:
# 5.0

# %%
round(math.sqrt(25))
# Out:
# 5

# %%
x = round(math.sqrt(25))
x
# Out:
# 5

# %%
math.floor(4.3)
# Out:
# 4

# %%
math.ceil(4.3) # ceil means will give rounding off value
# Out:
# 5

# %%
pow(5,3) # 5 power 3 = 125
# Out:
# 125

# %%
math.pi
# Out:
# 3.141592653589793

# %%
pi = 3.25 # we can change the original mathematical value of pi from 3.14 to 3.27 or anything.
pi
# Out:
# 3.25

# %%
help()  # help() -- if we want to any any informaation in python then we can use this(topics, objects, classess) --> once done enter 'q' or 'quit' or 'exit' for exit
# Out:
# Welcome to Python 3.13's help utility! If this is your first time using
# Python, you should definitely check out the tutorial at
# https://docs.python.org/3.13/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To get a list of available
# modules, keywords, symbols, or topics, enter "modules", "keywords",
# "symbols", or "topics".
#
# Each module also comes with a one-line summary of what it does; to list
# the modules whose name or summary contain a given string such as "spam",
# enter "modules spam".
#
# To quit this help utility and return to the interpreter,
# enter "q", "quit" or "exit".
# help>  topics
# Here is a list of available topics.  Enter any topic name to get more help.
#
# ASSERTION                 EXCEPTIONS                PACKAGES
# ASSIGNMENT                EXECUTION                 POWER
# ASSIGNMENTEXPRESSIONS     EXPRESSIONS               PRECEDENCE
# ...

# %%
from math import sqrt, pow # math has many functions, if we want to import specific function then use this
print(pow(2,3))
# Out:
# 8.0

# %%
import math as m
x = m.sqrt(49)
x
# Out:
# 7.0

# %%
m.ceil(x)
# Out:
# 7

# %%
m.ceil(7.1)
# Out:
# 8

# %%
print(math.e)
# Out:
# 2.718281828459045

# %% [markdown]
# # input() function

# %%
input()
# Out:
#  hello world
# 'hello world'

# %%
input()
# Out:
#  wohoo
# 'wohoo'

# %%
input()
input()
# Out:
#  hello
#  world
# 'world'

# %%
x = input() # why we re gettting 7 + 12 = 712 means input() will always take as string only, so if you need output typecast to int.
y = input()
z = x + y
print(f'addition of {x} and {y} is = {z}')
# Out:
#  7
#  12
# addition of 7 and 12 is = 712

# %%
a = input()  # error bcz input() will always takes as string only
b = input()
c = a * b

print(f'The multiplication of {a} and {b} is = {c}')
# Out:
#  53
#  24
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 3
#       1 a = input()  # error bcz input() will always takes as string only
#       2 b = input()
# ----> 3 c = a * b
#       5 print(f'The multiplication of {a} and {b} is = {c}')
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
print(type(a))
print(type(b))
# Out:
# <class 'str'>
# <class 'str'>

# %%
a = int(input()) # after typecasting now we got the value.
b = int(input())
c = a * b
print(f'The multiplication of {a} and {b} is = {c}')
# Out:
#  25
#  5
# The multiplication of 25 and 5 is = 125

# %%
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
x1 = input('Enter user_name: ')
x2 = input('Enter password: ')
z1 = x1 + x2
print(f'The User name {x1}')
print(f'and password is {x2}')
# Out:
# Enter user_name:  Mickel
# Enter password:  Jackson
# The User name Mickel
# and password is Jackson

# %%
str = input('enter a string')
print(str)
# Out:
# enter a string Hello
# Hello

# %%
str = input('enter a string')[0]
print(str)
# Out:
# enter a string hello
# h

# %%
str = input('enter a string')[::-3]
print(str)
# Out:
# enter a string hello world
# dooe

# %%
str = input('enter a string')[::4]
print(str)
# Out:
# enter a string hello world
# hor

# %%
str = input('enter a string')[2::4]
print(str)
# Out:
# enter a string hello world
# lwd

# %%
str = input('enter a string')[2:9:4]
print(str)

# %%
l->l lw
